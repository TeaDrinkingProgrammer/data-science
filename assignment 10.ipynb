# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv('steam.csv', sep=',')

# %%
df.pop('appid')
# Convert english too boolean
df['english'] = df['english'].astype('bool')
# set release date to datetime
df['release_date'] = pd.to_datetime(df['release_date'])
# create 3 seperate platform fields instead of 1
df['windows'], df['mac'], df['linux'] = df['platforms'].apply(lambda x: 'windows' in x),df['platforms'].apply(lambda x: 'mac' in x),df['platforms'].apply(lambda x: 'linux' in x)
df.drop(columns='platforms', inplace=True)
df['owners_low'] = df['owners'].apply(lambda x: x.split('-')[0]).astype('int')
df['owners_high'] = df['owners'].apply(lambda x: x.split('-')[1]).astype('int')
df['release_year'] = df['release_date'].dt.year
df.drop(columns='owners', inplace=True)
genres = df['genres'].apply(lambda x: x.split(';')[0])

# %%
medianPlaytimeFilter = df['median_playtime']> 0.5
ownersFilter = df['owners_low'] > 20000 #lowest range above 0
reviewFilter = df['positive_ratings'] > 5
noFreeGameFilter = df['price'] > 0.1

# %%
gameCorrelations = df.corr()
gameCorrelations.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# C:\Users\Stijn\AppData\Local\Temp/ipykernel_11924/4049258250.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   gameCorrelations.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# <style type="text/css">
# #T_16e37_row0_col0, #T_16e37_row1_col1, #T_16e37_row2_col2, #T_16e37_row3_col3, #T_16e37_row4_col4, #T_16e37_row5_col5, #T_16e37_row6_col6, #T_16e37_row7_col7, #T_16e37_row8_col8, #T_16e37_row9_col9, #T_16e37_row10_col10, #T_16e37_row11_col11, #T_16e37_row11_col12, #T_16e37_row12_col11, #T_16e37_row12_col12, #T_16e37_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_16e37_row0_col1, #T_16e37_row0_col5, #T_16e37_row1_col0, #T_16e37_row2_col4, #T_16e37_row2_col8, #T_16e37_row2_col11, #T_16e37_row2_col12, #T_16e37_row3_col8, #T_16e37_row4_col2, #T_16e37_row4_col8, #T_16e37_row5_col0, #T_16e37_row5_col8, #T_16e37_row6_col8, #T_16e37_row7_col8, #T_16e37_row8_col2, #T_16e37_row8_col3, #T_16e37_row8_col4, #T_16e37_row8_col5, #T_16e37_row8_col6, #T_16e37_row8_col7, #T_16e37_row8_col11, #T_16e37_row8_col12, #T_16e37_row8_col13, #T_16e37_row11_col2, #T_16e37_row11_col8, #T_16e37_row12_col2, #T_16e37_row12_col8, #T_16e37_row13_col8 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_16e37_row0_col2, #T_16e37_row1_col6, #T_16e37_row2_col0, #T_16e37_row2_col5, #T_16e37_row4_col10, #T_16e37_row5_col2, #T_16e37_row6_col1, #T_16e37_row7_col10, #T_16e37_row10_col4, #T_16e37_row10_col7 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_16e37_row0_col3, #T_16e37_row0_col4, #T_16e37_row0_col7, #T_16e37_row2_col3, #T_16e37_row3_col0, #T_16e37_row3_col2, #T_16e37_row4_col0, #T_16e37_row7_col0 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_16e37_row0_col6, #T_16e37_row0_col8, #T_16e37_row6_col0, #T_16e37_row8_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_16e37_row0_col9, #T_16e37_row1_col3, #T_16e37_row1_col4, #T_16e37_row3_col1, #T_16e37_row4_col1, #T_16e37_row9_col0 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_16e37_row0_col10, #T_16e37_row10_col0 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_16e37_row0_col11, #T_16e37_row0_col12, #T_16e37_row2_col6, #T_16e37_row4_col9, #T_16e37_row6_col2, #T_16e37_row9_col4, #T_16e37_row11_col0, #T_16e37_row12_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_16e37_row0_col13, #T_16e37_row9_col13, #T_16e37_row13_col0, #T_16e37_row13_col9 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_16e37_row1_col2, #T_16e37_row2_col1, #T_16e37_row2_col7, #T_16e37_row2_col10, #T_16e37_row7_col2, #T_16e37_row8_col10, #T_16e37_row10_col2, #T_16e37_row10_col8 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_16e37_row1_col5, #T_16e37_row2_col13, #T_16e37_row3_col9, #T_16e37_row5_col1, #T_16e37_row5_col10, #T_16e37_row7_col12, #T_16e37_row9_col3, #T_16e37_row10_col5, #T_16e37_row12_col7, #T_16e37_row13_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_16e37_row1_col7, #T_16e37_row7_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_16e37_row1_col8, #T_16e37_row8_col1 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_16e37_row1_col9, #T_16e37_row9_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_16e37_row1_col10, #T_16e37_row8_col9, #T_16e37_row9_col8, #T_16e37_row10_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_16e37_row1_col11, #T_16e37_row11_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_16e37_row1_col12, #T_16e37_row12_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_16e37_row1_col13, #T_16e37_row13_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_16e37_row2_col9, #T_16e37_row9_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_16e37_row3_col4, #T_16e37_row4_col3 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_16e37_row3_col5, #T_16e37_row5_col3 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_16e37_row3_col6, #T_16e37_row3_col7, #T_16e37_row6_col3, #T_16e37_row6_col7, #T_16e37_row6_col11, #T_16e37_row6_col12, #T_16e37_row7_col3, #T_16e37_row7_col6, #T_16e37_row11_col6, #T_16e37_row12_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_16e37_row3_col10, #T_16e37_row9_col11, #T_16e37_row9_col12, #T_16e37_row10_col3, #T_16e37_row11_col9, #T_16e37_row12_col9 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_16e37_row3_col11, #T_16e37_row11_col3 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_16e37_row3_col12, #T_16e37_row12_col3 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_16e37_row3_col13, #T_16e37_row13_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_16e37_row4_col5, #T_16e37_row5_col4 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_16e37_row4_col6, #T_16e37_row6_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_16e37_row4_col7, #T_16e37_row5_col7, #T_16e37_row7_col4, #T_16e37_row7_col5, #T_16e37_row10_col11, #T_16e37_row10_col12, #T_16e37_row11_col10, #T_16e37_row12_col10 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_16e37_row4_col11, #T_16e37_row11_col4 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_16e37_row4_col12, #T_16e37_row12_col4 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_16e37_row4_col13, #T_16e37_row6_col13, #T_16e37_row13_col4, #T_16e37_row13_col6 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_16e37_row5_col6, #T_16e37_row6_col5 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_16e37_row5_col9, #T_16e37_row7_col11, #T_16e37_row9_col5, #T_16e37_row11_col7 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_16e37_row5_col11, #T_16e37_row5_col12, #T_16e37_row11_col5, #T_16e37_row12_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_16e37_row5_col13, #T_16e37_row13_col5 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_16e37_row6_col9, #T_16e37_row6_col10, #T_16e37_row7_col9, #T_16e37_row9_col6, #T_16e37_row9_col7, #T_16e37_row10_col6 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_16e37_row7_col13, #T_16e37_row13_col7 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_16e37_row9_col10, #T_16e37_row10_col9 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_16e37_row10_col13, #T_16e37_row13_col10 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_16e37_row11_col13, #T_16e37_row12_col13, #T_16e37_row13_col11, #T_16e37_row13_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_16e37_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >english</th>
#       <th class="col_heading level0 col1" >required_age</th>
#       <th class="col_heading level0 col2" >achievements</th>
#       <th class="col_heading level0 col3" >positive_ratings</th>
#       <th class="col_heading level0 col4" >negative_ratings</th>
#       <th class="col_heading level0 col5" >average_playtime</th>
#       <th class="col_heading level0 col6" >median_playtime</th>
#       <th class="col_heading level0 col7" >price</th>
#       <th class="col_heading level0 col8" >windows</th>
#       <th class="col_heading level0 col9" >mac</th>
#       <th class="col_heading level0 col10" >linux</th>
#       <th class="col_heading level0 col11" >owners_low</th>
#       <th class="col_heading level0 col12" >owners_high</th>
#       <th class="col_heading level0 col13" >release_year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16e37_level0_row0" class="row_heading level0 row0" >english</th>
#       <td id="T_16e37_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_16e37_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_16e37_row0_col2" class="data row0 col2" >0.01</td>
#       <td id="T_16e37_row0_col3" class="data row0 col3" >0.01</td>
#       <td id="T_16e37_row0_col4" class="data row0 col4" >0.01</td>
#       <td id="T_16e37_row0_col5" class="data row0 col5" >0.00</td>
#       <td id="T_16e37_row0_col6" class="data row0 col6" >-0.00</td>
#       <td id="T_16e37_row0_col7" class="data row0 col7" >0.01</td>
#       <td id="T_16e37_row0_col8" class="data row0 col8" >-0.00</td>
#       <td id="T_16e37_row0_col9" class="data row0 col9" >0.06</td>
#       <td id="T_16e37_row0_col10" class="data row0 col10" >0.06</td>
#       <td id="T_16e37_row0_col11" class="data row0 col11" >0.01</td>
#       <td id="T_16e37_row0_col12

# %%
correlation2 = df[['owners_high','positive_ratings']]
correlation2.corr()
# Out:
#                   owners_high  positive_ratings
# owners_high          1.000000          0.712447
# positive_ratings     0.712447          1.000000

# %%
df.plot(kind='scatter', x='owners_high',y='positive_ratings')
# Out:
# <AxesSubplot:xlabel='owners_high', ylabel='positive_ratings'>

# %%
df[df['owners_high'] < 100000000].plot(kind='scatter', x='owners_high',y='positive_ratings')
# Out:
# <AxesSubplot:xlabel='owners_high', ylabel='positive_ratings'>

# %% [markdown]
# It does match my expectation, as you will have more (positive) reviews if more people play your game
